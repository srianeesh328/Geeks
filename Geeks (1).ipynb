# %%
import pandas as pd

s1 = pd.Series([1,2]) 
s2 = pd.Series(["Ashish", "Sid"]) 
# framing series objects into data 
df = pd.DataFrame([s1,s2]) 
# show the data frame 
df 
  
# data framing in another way 
# taking index and column values 
dframe = pd.DataFrame([[1,2],["Ashish", "Sid"]], 
        index=["r1", "r2"], 
        columns=["c1", "c2"]) 
dframe 
  
# framing in another way  
# dict-like container 
dframe = pd.DataFrame({ 
        "c1": [1, "Ashish"], 
        "c2": [2, "Sid"]}) 
dframe
# Out:
#        c1   c2
# 0       1    2
# 1  Ashish  Sid

# %%
import pandas as pd
df = pd.read_csv('CountryData1.csv')
  
# Prints the first 5 rows of a DataFrame as default 
df.head() 
  
# Prints no. of rows and columns of a DataFrame 
df.shape
# Out:
# (29, 16)

# %%
# prints first 5 rows and every column which replicates df.head() 
df.iloc[0:5,:] 
# prints entire rows and columns 
df.iloc[:,:] 
# prints from 5th rows and first 5 columns 
df.iloc[5:,:5]
# Out:
#     Series Code Frequency                                             Series  \
# 5   SH_DYN_MORT    Annual                          Under-five mortality rate
# 6   SH_DYN_MORT    Annual                          Under-five mortality rate
# 7   SH_DYN_MORT    Annual                          Under-five mortality rate
# 8   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 9   SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 10  SH_STA_BRTC    Annual        Births attended by skilled health personnel
# 11  SH_STA_MORT    Annual                           Maternal mortality ratio
# 12  SH_STA_MORT    Annual                           Maternal mortality ratio
# 13  SH_STA_MORT    Annual                           Maternal mortality ratio
# 14  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 15  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 16  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 17  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 18  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 19  SH_TBS_PREV    Annual                       Tuberculosis prevalence rate
# 20  SI_POV_NAHC    Annual             Population below national poverty line
# 21  SI_POV_NAHC    Annual             Population below national poverty line
# 22  SI_POV_NAHC    Annual             Population below national poverty line
# 23  SI_POV_NAHC    Annual             Population below national poverty line
# 24  SL_EMP_NAGR    Annual  Share women in wage employment in the non-agri...
# 25  SL_EMP_NAGR    Annual  Share women in wage employment in the non-agri...
# 26  SN_STA_MALN    Annual        Children moderately or severely underweight
# 27  SN_STA_MALN    Annual        Children moderately or severely underweight
# 28  SN_STA_MALN    Annual        Children moderately or severely underweight
#
#        Units of measurement                Location
# 5     Per 1,000 live births  Total (national level)
# 6     Per 1,000 live births  Total (national level)
# 7     Per 1,000 live births  Total (national level)
# 8                   Percent  Total (national level)
# 9                   Percent  Total (national level)
# 10                  Percent  Total (national level)
# 11  Per 100,000 live births  Total (national level)
# 12  Per 100,000 live births  Total (national level)
# 13  Per 100,000 live births  Total (national level)
# 14   Per 100,000 population  Total (national level)
# 15   Per 100,000 population  Total (national level)
# 16   Per 100,000 population  Total (national level)
# 17   Per 100,000 population  Total (national level)
# 18   Per 100,000 population  Total (national level)
# 19   Per 100,000 population  Total (national level)
# 20                  Percent  Total (national level)
# 21                  Percent  Total (national level)
# 22                  Percent  Total (national level)
# 23                  Percent  Total (national level)
# 24                  Percent  Total (national level)
# 25                  Percent  Total (national level)
# 26                  Percent  Total (national level)
# 27                  Percent  Total (national level)
# 28                  Percent  Total (national level)

# %%
df.loc[0:5,:] 
# prints from 5th rows onwards and entire columns 
df = df.loc[5:,:]

# %%
df.describe() 
# for computing correlations 
df.corr() 
# computes numerical data ranks 
df.rank()
# Out:
#     Series Code  Frequency  Series  Units of measurement  Location  Age group  \
# 5           2.0       12.5    23.0                   2.0      12.5       21.5
# 6           2.0       12.5    23.0                   2.0      12.5       21.5
# 7           2.0       12.5    23.0                   2.0      12.5       21.5
# 8           5.0       12.5     2.0                  18.5      12.5       17.0
# 9           5.0       12.5     2.0                  18.5      12.5       17.0
# 10          5.0       12.5     2.0                  18.5      12.5       17.0
# 11          8.0       12.5     8.0                   5.0      12.5        8.0
# 12          8.0       12.5     8.0                   5.0      12.5        8.0
# 13          8.0       12.5     8.0                   5.0      12.5        8.0
# 14         12.5       12.5    18.5                   9.5      12.5        8.0
# 15         12.5       12.5    18.5                   9.5      12.5        8.0
# 16         12.5       12.5    18.5                   9.5      12.5        8.0
# 17         12.5       12.5    18.5                   9.5      12.5        8.0
# 18         12.5       12.5    18.5                   9.5      12.5        8.0
# 19         12.5       12.5    18.5                   9.5      12.5        8.0
# 20         17.5       12.5    11.5                  18.5      12.5        8.0
# 21         17.5       12.5    11.5                  18.5      12.5        8.0
# 22         17.5       12.5    11.5                  18.5      12.5        8.0
# 23         17.5       12.5    11.5                  18.5      12.5        8.0
# 24         20.5       12.5    14.5                  18.5      12.5        8.0
# 25         20.5       12.5    14.5                  18.5      12.5        8.0
# 26         23.0       12.5     5.0                  18.5      12.5       21.5
# 27         23.0       12.5     5.0                  18.5      12.5       21.5
# 28         23.0       12.5     5.0                  18.5      12.5       21.5
#
#      Sex  Reference Area  Source type  Time period  Observation Value  \
# 5    8.5            12.5         12.5          3.0               15.0
# 6    8.5            12.5         12.5          8.0               14.0
# 7    8.5            12.5         12.5         22.5               13.0
# 8   23.0            12.5         12.5          3.0                6.0
# 9   23.0            12.5         12.5          8.0                8.0
# 10  23.0            12.5         12.5         22.5               11.0
# 11  19.0            12.5         12.5          6.0               22.0
# 12  19.0            12.5         12.5         12.5               19.0
# 13  19.0            12.5         12.5         15.5               17.0
# 14   8.5            12.5         12.5          1.0               24.0
# 15   8.5            12.5         12.5         12.5               23.0
# 16   8.5            12.5         12.5         14.0               21.0
# 17   8.5            12.5         12.5         15.5               20.0
# 18   8.5            12.5         12.5         17.0               16.0
# 19   8.5            12.5         12.5         19.0               18.0
# 20   8.5            12.5         12.5          5.0                7.0
# 21   8.5            12.5         12.5         10.5                4.0
# 22   8.5            12.5         12.5         19.0                5.0
# 23   8.5            12.5         12.5         22.5                3.0
# 24  19.0            12.5         12.5         10.5                1.0
# 25  19.0            12.5         12.5         19.0                2.0
# 26   8.5            12.5         12.5          3.0               12.0
# 27   8.5            12.5         12.5          8.0               10.0
# 28   8.5            12.5         12.5         22.5                9.0
#
#     Unit multiplier  Nature of data points  Time period details  \
# 5              12.5                   12.5                  3.0
# 6              12.5                   12.5                  8.0
# 7              12.5                   12.5                 22.5
# 8              12.5                   12.5                  3.0
# 9              12.5                   12.5                  8.0
# 10             12.5                   12.5                 22.5
# 11             12.5                   12.5                  6.0
# 12             12.5                   12.5                 12.5
# 13             12.5                   12.5                 15.5
# 14             12.5                   12.5                  1.0
# 15             12.5                   12.5                 12.5
# 16             12.5                   12.5                 14.0
# 17             12.5                   12.5                 15.5
# 18             12.5                   12.5                 17.0
# 19             12.5                   12.5                 19.0
# 20             12.5                   12.5                  5.0
# 21             12.5                   12.5                 10.5
# 22             12.5                   12.5                 19.0
# 23             12.5                   12.5                 22.5
# 24             12.5                   12.5                 10.5
# 25             12.5                   12.5                 19.0
# 26             12.5                   12.5                  3.0
# 27             12.5                   12.5                  8.0
# 28             12.5                   12.5                 22.5
#
#     Source details  Footnotes
# 5              5.0        NaN
# 6              5.0        NaN
# 7              5.0        NaN
# 8              5.0        NaN
# 9              5.0        NaN
# 10             5.0        NaN
# 11            17.0        NaN
# 12            17.0        NaN
# 13            17.0        NaN
# 14             NaN        NaN
# 15             NaN        NaN
# 16             NaN        NaN
# 17             NaN        NaN
# 18             NaN        NaN
# 19             NaN        NaN
# 20            13.5        NaN
# 21            13.5        NaN
# 22            13.5        NaN
# 23            13.5        NaN
# 24            10.5        NaN
# 25            10.5        NaN
# 26             5.0        NaN
# 27             5.0        NaN
# 28             5.0        NaN

# %%
# import the required module  
import matplotlib.pyplot as plt 
# plot a histogram  
df['Observation Value'].hist(bins=10) 
  
# shows presence of a lot of outliers/extreme values 
df.boxplot(column='Observation Value', by = 'Time period') 
  
# plotting points as a scatter plot 
x = df["Observation Value"] 
y = df["Time period"] 
plt.scatter(x, y, label= "stars", color= "m",  
            marker= "*", s=30) 
# x-axis label 
plt.xlabel('Observation Value') 
# frequency label 
plt.ylabel('Time period') 
# function to show the plot 
plt.show()

# %%
df.describe()
df.corr()
df.rank()
# Out:
#     Series Code  Frequency  Series  Units of measurement  Location  Age group  \
# 5           2.0       12.5    23.0                   2.0      12.5       21.5
# 6           2.0       12.5    23.0                   2.0      12.5       21.5
# 7           2.0       12.5    23.0                   2.0      12.5       21.5
# 8           5.0       12.5     2.0                  18.5      12.5       17.0
# 9           5.0       12.5     2.0                  18.5      12.5       17.0
# 10          5.0       12.5     2.0                  18.5      12.5       17.0
# 11          8.0       12.5     8.0                   5.0      12.5        8.0
# 12          8.0       12.5     8.0                   5.0      12.5        8.0
# 13          8.0       12.5     8.0                   5.0      12.5        8.0
# 14         12.5       12.5    18.5                   9.5      12.5        8.0
# 15         12.5       12.5    18.5                   9.5      12.5        8.0
# 16         12.5       12.5    18.5                   9.5      12.5        8.0
# 17         12.5       12.5    18.5                   9.5      12.5        8.0
# 18         12.5       12.5    18.5                   9.5      12.5        8.0
# 19         12.5       12.5    18.5                   9.5      12.5        8.0
# 20         17.5       12.5    11.5                  18.5      12.5        8.0
# 21         17.5       12.5    11.5                  18.5      12.5        8.0
# 22         17.5       12.5    11.5                  18.5      12.5        8.0
# 23         17.5       12.5    11.5                  18.5      12.5        8.0
# 24         20.5       12.5    14.5                  18.5      12.5        8.0
# 25         20.5       12.5    14.5                  18.5      12.5        8.0
# 26         23.0       12.5     5.0                  18.5      12.5       21.5
# 27         23.0       12.5     5.0                  18.5      12.5       21.5
# 28         23.0       12.5     5.0                  18.5      12.5       21.5
#
#      Sex  Reference Area  Source type  Time period  Observation Value  \
# 5    8.5            12.5         12.5          3.0               15.0
# 6    8.5            12.5         12.5          8.0               14.0
# 7    8.5            12.5         12.5         22.5               13.0
# 8   23.0            12.5         12.5          3.0                6.0
# 9   23.0            12.5         12.5          8.0                8.0
# 10  23.0            12.5         12.5         22.5               11.0
# 11  19.0            12.5         12.5          6.0               22.0
# 12  19.0            12.5         12.5         12.5               19.0
# 13  19.0            12.5         12.5         15.5               17.0
# 14   8.5            12.5         12.5          1.0               24.0
# 15   8.5            12.5         12.5         12.5               23.0
# 16   8.5            12.5         12.5         14.0               21.0
# 17   8.5            12.5         12.5         15.5               20.0
# 18   8.5            12.5         12.5         17.0               16.0
# 19   8.5            12.5         12.5         19.0               18.0
# 20   8.5            12.5         12.5          5.0                7.0
# 21   8.5            12.5         12.5         10.5                4.0
# 22   8.5            12.5         12.5         19.0                5.0
# 23   8.5            12.5         12.5         22.5                3.0
# 24  19.0            12.5         12.5         10.5                1.0
# 25  19.0            12.5         12.5         19.0                2.0
# 26   8.5            12.5         12.5          3.0               12.0
# 27   8.5            12.5         12.5          8.0               10.0
# 28   8.5            12.5         12.5         22.5                9.0
#
#     Unit multiplier  Nature of data points  Time period details  \
# 5              12.5                   12.5                  3.0
# 6              12.5                   12.5                  8.0
# 7              12.5                   12.5                 22.5
# 8              12.5                   12.5                  3.0
# 9              12.5                   12.5                  8.0
# 10             12.5                   12.5                 22.5
# 11             12.5                   12.5                  6.0
# 12             12.5                   12.5                 12.5
# 13             12.5                   12.5                 15.5
# 14             12.5                   12.5                  1.0
# 15             12.5                   12.5                 12.5
# 16             12.5                   12.5                 14.0
# 17             12.5                   12.5                 15.5
# 18             12.5                   12.5                 17.0
# 19             12.5                   12.5                 19.0
# 20             12.5                   12.5                  5.0
# 21             12.5                   12.5                 10.5
# 22             12.5                   12.5                 19.0
# 23             12.5                   12.5                 22.5
# 24             12.5                   12.5                 10.5
# 25             12.5                   12.5                 19.0
# 26             12.5                   12.5                  3.0
# 27             12.5                   12.5                  8.0
# 28             12.5                   12.5                 22.5
#
#     Source details  Footnotes
# 5              5.0        NaN
# 6              5.0        NaN
# 7              5.0        NaN
# 8              5.0        NaN
# 9              5.0        NaN
# 10             5.0        NaN
# 11            17.0        NaN
# 12            17.0        NaN
# 13            17.0        NaN
# 14             NaN        NaN
# 15             NaN        NaN
# 16             NaN        NaN
# 17             NaN        NaN
# 18             NaN        NaN
# 19             NaN        NaN
# 20            13.5        NaN
# 21            13.5        NaN
# 22            13.5        NaN
# 23            13.5        NaN
# 24            10.5        NaN
# 25            10.5        NaN
# 26             5.0        NaN
# 27             5.0        NaN
# 28             5.0        NaN

# %%
# import the required module  
import matplotlib.pyplot as plt 
# plot a histogram  
df['Observation Value'].hist(bins=10) 
  
# shows presence of a lot of outliers/extreme values 
df.boxplot(column='Observation Value', by = 'Time period') 
  
# plotting points as a scatter plot 
x = df["Observation Value"] 
y = df["Time period"] 
plt.scatter(x, y, label= "stars", color= "m",  
            marker= "*", s=30) 
# x-axis label 
plt.xlabel('Observation Value') 
# frequency label 
plt.ylabel('Time period') 
# function to show the plot 
plt.show()

# %%
import pandas as pd 

# assigning three series to s1, s2, s3 
s1 = pd.Series([0, 4, 8]) 
s2 = pd.Series([1, 5, 9]) 
s3 = pd.Series([2, 6, 10]) 
  
# taking index and column values 
dframe = pd.DataFrame([s1, s2, s3]) 
  
# assign column name 
dframe.columns =['Geeks', 'For', 'Geeks'] 
  
# write data to csv file 
dframe.to_csv('geeksforgeeks.csv', index = False)   
dframe.to_csv('geeksforgeeks1.csv', index = True)

# %%
import pandas as pd 
import numpy as np  
# Create a DataFrame 
dframe = pd.DataFrame({'Geeks': [23, 24, 22],  
                       'For': [10, 12, np.nan], 
                       'geeks': [0, np.nan, np.nan]}, 
                       columns =['Geeks', 'For', 'geeks']) 
  
# This will remove all the 
# rows with NAN values 
  
# If axis is not defined then 
# it is along rows i.e. axis = 0 
dframe.dropna(inplace = True) 
print(dframe) 
  
# if axis is equal to 1 
dframe.dropna(axis = 1, inplace = True) 
  
print(dframe)
# Out:
#    Geeks   For  geeks
# 0     23  10.0    0.0
#    Geeks   For  geeks
# 0     23  10.0    0.0

# %%
import numpy as np 
import pandas as pd 
  
# Create a DataFrame 
dframe = pd.DataFrame({'Geeks': [23, 24, 22],  
                        'For': [10, 12, np.nan], 
                        'geeks': [0, np.nan, np.nan]}, 
                        columns = ['Geeks', 'For', 'geeks']) 
  
# Use fillna of complete Dataframe  
  
# value function will be applied on every column 
dframe.fillna(value = dframe.mean(), inplace = True) 
print(dframe) 
  
# filling value of one column 
dframe['For'].fillna(value = dframe['For'].mean(), 
                                    inplace = True) 
print(dframe)
# Out:
#    Geeks   For  geeks
# 0     23  10.0    0.0
# 1     24  12.0    0.0
# 2     22  11.0    0.0
#    Geeks   For  geeks
# 0     23  10.0    0.0
# 1     24  12.0    0.0
# 2     22  11.0    0.0

# %%
import pandas as pd 
import numpy as np 
  
# create DataFrame 
dframe = pd.DataFrame({'Geeks': [23, 24, 22, 22, 23, 24],  
                        'For': [10, 12, 13, 14, 15, 16], 
                        'geeks': [122, 142, 112, 122, 114, 112]}, 
                        columns = ['Geeks', 'For', 'geeks'])  
  
# Apply groupby and aggregate function 
# max to find max value of column  
  
# &quot;For&quot; and column &quot;geeks&quot; for every 
# different value of column &quot;Geeks&quot;. 
  
print(dframe.groupby(['Geeks']).max())
# Out:
#        For  geeks
# Geeks
# 22      14    122
# 23      15    122
# 24      16    142
